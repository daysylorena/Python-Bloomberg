# %% [markdown]
# <a href="https://colab.research.google.com/github/daysylorena/Python-Bloomberg/blob/main/Projeto_Python_Casa_de_Hogwarts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Qual será a sua casa de Hogwarts? \n Responda as perguntas a seguir para saber a escolha do Chapéu Seletor para você:")

opcaoA = 0
opcaoB = 0
opcaoC = 0
opcaoD = 0

def sonserina():
  print("O Chapéu Seletor diz:\n""\"Quem sabe a Sonserina será a sua casa,\nE ali fará seus verdadeiros amigos,\nHomens de astúcia que usam quaisquer meios para atingir os fins que antes colimaram. Sim... SONSERINA!\"")

def corvinal():
  print("O Chapéu Seletor diz:\n""\"Ou será a velha e sábia Corvinal,\nA casa dos que tem a mente sempre alerta,\nOnde os homens de grande espírito e saber\nSempre encontrarão companheiros seus iguais. É isso mesmo... CORVINAL!\"")

def grifinoria():
  print("O Chapéu Seletor diz:\n""\"Quem sabe sua morada é a Grifinória, \nCasa onde habitam os corações indômitos,\nOusadia e sangue-frio e nobreza Destacam os alunos da Grifinória dos demais. Já sei... GRIFINÓRIA!\"")

def lufalufa():
  print("O Chapéu Seletor diz:\n""\"Quem sabe é na Lufa-Lufa que você vai morar,\nOnde seus moradores são justos e leais,\nPacientes, sinceros, sem medo da dor. Hmmm... LUFA-LUFA!\"")
# Out:
# Qual será a sua casa de Hogwarts?
#  Responda as perguntas a seguir para saber a escolha do Chapéu Seletor para você:

# %%
print("1) Qual das seguintes habilidades tem mais a ver com você?")
resp = input(" A- comunicação \n B- atenção aos detalhes \n C- proatividade \n D- trabalho em equipe \n Resposta: ")
while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
  resp = input("ERRO. Essa não é uma opção válida. Escolha uma alternativa: ")
if resp == "a" or resp == "A":
  opcaoA = opcaoA + 1
if resp == "b" or resp == "B":
  opcaoB = opcaoB + 1
if resp == "c" or resp == "C":
  opcaoC = opcaoC + 1
if resp == "d" or resp == "D":
  opcaoD = opcaoD + 1
print("2) Qual dessas mentalidades está mais presente na sua personalidade?")
resp = input(" A- mentalidade de crescimento \n B- orientação ao futuro \n C- persistência \n D- responsabilidade pessoal \n Resposta: ")
while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
  resp = input("ERRO. Essa não é uma opção válida. Escolha uma alternativa: ")
if resp == "a" or resp == "A":
  opcaoA = opcaoA + 1
if resp == "b" or resp == "B":
  opcaoB = opcaoB + 1
if resp == "c" or resp == "C":
  opcaoC = opcaoC + 1
if resp == "d" or resp == "D":
  opcaoD = opcaoD + 1
print("3) Como programador(a), qual dos adjetivos abaixo mais te ofenderia caso te chamassem?")
resp = input(" A- medíocre \n B- ignorante \n C- covarde \n D- egoísta \n Resposta: ")
while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
  resp = input("ERRO. Essa não é uma opção válida. Escolha uma alternativa: ")
if resp == "a" or resp == "A":
  opcaoA = opcaoA + 1
if resp == "b" or resp == "B":
  opcaoB = opcaoB + 1
if resp == "c" or resp == "C":
  opcaoC = opcaoC + 1
if resp == "d" or resp == "D":
  opcaoD = opcaoD + 1
print("4) O que você prefere fazer no seu tempo livre?")
resp = input(" A- compras \n B- ler ou assistir uma série \n C- jogar online \n D- colocar o papo em dia \n Resposta: ")
while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
  resp = input("ERRO. Essa não é uma opção válida. Escolha uma alternativa: ")
if resp == "a" or resp == "A":
  opcaoA = opcaoA + 1
if resp == "b" or resp == "B":
  opcaoB = opcaoB + 1
if resp == "c" or resp == "C":
  opcaoC = opcaoC + 1
if resp == "d" or resp == "D":
  opcaoD = opcaoD + 1
print("5) Em uma história, que personalidade você prefere que o/a protagonista tenha?")
resp = input(" A- que seja mais impulsivo/a e direto/a \n B- que seja mais sábio e aja como líder \n C- que seja paciente, mas não leve desaforo para casa \n D- que tenha uma empatia enorme e bom humor \n Resposta: ")
while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
  resp = input("ERRO. Essa não é uma opção válida. Escolha uma alternativa: ")
if resp == "a" or resp == "A":
  opcaoA = opcaoA + 1
if resp == "b" or resp == "B":
  opcaoB = opcaoB + 1
if resp == "c" or resp == "C":
  opcaoC = opcaoC + 1
if resp == "d" or resp == "D":
  opcaoD = opcaoD + 1
print("6) Qual estilo de jogos você prefere?")
resp = input(" A- estratégia \n B- tabuleiro \n C- luta \n D- cartas \n Resposta: ")
while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
  resp = input("ERRO. Essa não é uma opção válida. Escolha uma alternativa: ")
if resp == "a" or resp == "A":
  opcaoA = opcaoA + 1
if resp == "b" or resp == "B":
  opcaoB = opcaoB + 1
if resp == "c" or resp == "C":
  opcaoC = opcaoC + 1
if resp == "d" or resp == "D":
  opcaoD = opcaoD + 1
print("7) Com qual personagem de Turma da Mônica você mais se identifica?")
resp = input(" A- Cebolinha \n B- Franjinha \n C- Mônica \n D- Magali \n Resposta: ")
while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
  resp = input("ERRO. Essa não é uma opção válida. Escolha uma alternativa: ")
if resp == "a" or resp == "A":
  opcaoA = opcaoA + 1
if resp == "b" or resp == "B":
  opcaoB = opcaoB + 1
if resp == "c" or resp == "C":
  opcaoC = opcaoC + 1
if resp == "d" or resp == "D":
  opcaoD = opcaoD + 1

casas = [opcaoA, opcaoB, opcaoC, opcaoD]

if opcaoA > opcaoB and opcaoA > opcaoC and opcaoA > opcaoD:
  sonserina()
elif opcaoB > opcaoA and opcaoB > opcaoC and opcaoB > opcaoD:
  corvinal()
elif opcaoC > opcaoA and opcaoC > opcaoB and opcaoC > opcaoD:
  grifinoria()
elif opcaoD > opcaoA and opcaoD > opcaoB and opcaoD > opcaoC:
  lufalufa()
elif max(casas) == 2:
  print("O Chapéu Seletor diz: \"Hmmm, intrigante... Você prefere ter uma tatuagem de:")
  resp = input(" a- caveira \n b- coruja \n c- tigre \n d- cachorro \n Resposta: ")
  while resp != "a" and resp != "A" and resp != "b" and resp != "B" and resp != "c" and resp != "C" and resp != "d" and resp != "D":
    resp = input("O Chapéu Seletor diz: \"Não entendi direito, pode responder novamente? Você prefere ter uma tatuagem de:")
  if resp == "a" or resp == "A":
    sonserina()
  if resp == "b" or resp == "B":
    corvinal()
  if resp == "c" or resp == "C":
    grifinoria()
  if resp == "d" or resp == "D":
    lufalufa()
elif opcaoC == opcaoD:
  print("O Chapéu Seletor diz: \"Hmmm, intrigante... Você prefere ter uma tatuagem de:")
  resp = input(" a- tigre \n b- cachorro \n Resposta: ")
  while resp != "a" and resp != "A" and resp != "b" and resp != "B":
    resp = input("O Chapéu Seletor diz: \"Não entendi direito, pode responder novamente? Você prefere ter uma tatuagem de:")
  if resp == "a" or resp == "A":
    grifinoria()
  if resp == "b" or resp == "B":
    lufalufa()
elif opcaoB == opcaoC:
  print("O Chapéu Seletor diz: \"Hmmm, intrigante... Você prefere ter uma tatuagem de:")
  resp = input(" a- coruja \n b- tigre \n Resposta: ")
  while resp != "a" and resp != "A" and resp != "b" and resp != "B":
    resp = input("O Chapéu Seletor diz: \"Não entendi direito, pode responder novamente? Você prefere ter uma tatuagem de:")
  if resp == "a" or resp == "A":
    corvinal()
  if resp == "b" or resp == "B":
    grifinoria()
elif opcaoB == opcaoD:
  print("O Chapéu Seletor diz: \"Hmmm, intrigante... Você prefere ter uma tatuagem de:")
  resp = input(" a- coruja \n b- cachorro \n Resposta: ")
  while resp != "a" and resp != "A" and resp != "b" and resp != "B":
    resp = input("O Chapéu Seletor diz: \"Não entendi direito, pode responder novamente? Você prefere ter uma tatuagem de:")
  if resp == "a" or resp == "A":
    corvinal()
  if resp == "b" or resp == "B":
    lufalufa()
elif opcaoA == opcaoB:
  print("O Chapéu Seletor diz: \"Hmmm, intrigante... Você prefere ter uma tatuagem de:")
  resp = input(" a- caveira \n b- coruja \n Resposta: ")
  while resp != "a" and resp != "A" and resp != "b" and resp != "B":
    resp = input("O Chapéu Seletor diz: \"Não entendi direito, pode responder novamente? Você prefere ter uma tatuagem de:")
  if resp == "a" or resp == "A":
    sonserina()
  if resp == "b" or resp == "B":
    corvinal()
elif opcaoA == opcaoB:
  print("O Chapéu Seletor diz: \"Hmmm, intrigante... Você prefere ter uma tatuagem de:")
  resp = input(" a- caveira \n b- tigre \n Resposta: ")
  while resp != "a" and resp != "A" and resp != "b" and resp != "B":
    resp = input("O Chapéu Seletor diz: \"Não entendi direito, pode responder novamente? Você prefere ter uma tatuagem de:")
  if resp == "a" or resp == "A":
    sonserina()
  if resp == "b" or resp == "B":
    grifinoria()
elif opcaoA == opcaoB:
  print("O Chapéu Seletor diz: \"Hmmm, intrigante... Você prefere ter uma tatuagem de:")
  resp = input(" a- caveira \n b- cachorro \n Resposta: ")
  while resp != "a" and resp != "A" and resp != "b" and resp != "B":
    resp = input("O Chapéu Seletor diz: \"Não entendi direito, pode responder novamente? Você prefere ter uma tatuagem de:")
  if resp == "a" or resp == "A":
    sonserina()
  if resp == "b" or resp == "B":
    lufalufa()
# Out:
# Qual será a sua casa de Hogwarts?
#  Responda as perguntas a seguir para saber a escolha do Chapéu Seletor para você:
# 1) Qual das seguintes habilidades tem mais a ver com você?
#  A- comunicação
#  B- atenção aos detalhes
#  C- proatividade
#  D- trabalho em equipe
#  Resposta: a
# 2) Qual dessas mentalidades está mais presente na sua personalidade?
#  A- mentalidade de crescimento
#  B- orientação ao futuro
#  C- persistência
#  D- responsabilidade pessoal
#  Resposta: a
# 3) Como programador(a), qual dos adjetivos abaixo mais te ofenderia caso te chamassem?
#  A- medíocre
#  B- ignorante
#  C- covarde
#  D- egoísta
#  Resposta: a
# 4) O que você prefere fazer no seu tempo livre?
#  A- compras
#  B- ler ou assistir uma série
#  C- jogar online
#  D- colocar o papo em dia
#  Resposta: b
# 5) Em uma história, que personalidade você prefere que o/a protagonista tenha?
#  A- que seja mais impulsivo/a e direto/a
#  B- que seja mais sábio e aja como líder
# ...
